# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - While looking at the data in better forms, it seems there is a strong correlation between weight and tumor volume for capomulin treated mice. The more the mouse weighed, the bigger the tumor is.
# - Most mice were treated with Remicane and Capomulin regimens and their final tumor volumes were lower.
# - Mouse L509 responded to the treatment plan of Capomulin and it's tumor volume decreased.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "Module5/Mouse_metadata.csv"
study_results_path = "Module5/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
study_data_complete = pd.merge(study_results, mouse_metadata, how = "left", on = "Mouse ID")


# Display the data table for preview
study_data_complete.head(10)
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
# 5     h246          0                45.0                 0     Ketapril
# 6     p189          0                45.0                 0     Ketapril
# 7     n923          0                45.0                 0     Ketapril
# 8     q119          0                45.0                 0     Ketapril
# 9     f993          0                45.0                 0     Naftisol
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# ...

# %%
# Checking the number of mice.
len(study_data_complete["Mouse ID"].unique())
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse_ids = study_data_complete.loc[study_data_complete.duplicated(subset = ["Mouse ID", "Timepoint"]), "Mouse ID"].unique()
duplicate_mouse_ids[0]
# Out:
# 'g989'

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_data = study_data_complete.loc[study_data_complete["Mouse ID"] ==duplicate_mouse_ids[0]]
duplicate_mouse_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_study_data_complete = study_data_complete[study_data_complete["Mouse ID"].isin(duplicate_mouse_ids)== False]
clean_study_data_complete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
len(clean_study_data_complete["Mouse ID"].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
#calculate the mean
means = clean_study_data_complete.groupby("Drug Regimen").mean("Tumor Volume (mm3)")
means["Tumor Volume (mm3)"]
# Out:
# Drug Regimen
# Capomulin    40.675741
# Ceftamin     52.591172
# Infubinol    52.884795
# Ketapril     55.235638
# Naftisol     54.331565
# Placebo      54.033581
# Propriva     52.320930
# Ramicane     40.216745
# Stelasyn     54.233149
# Zoniferol    53.236507
# Name: Tumor Volume (mm3), dtype: float64

# %%
#calculate the medians
medians = clean_study_data_complete.groupby("Drug Regimen").median("Tumor Volume (mm3)")
medians["Tumor Volume (mm3)"]
# Out:
# Drug Regimen
# Capomulin    41.557809
# Ceftamin     51.776157
# Infubinol    51.820584
# Ketapril     53.698743
# Naftisol     52.509285
# Placebo      52.288934
# Propriva     50.446266
# Ramicane     40.673236
# Stelasyn     52.431737
# Zoniferol    51.818479
# Name: Tumor Volume (mm3), dtype: float64

# %%
#calculate the variances
variances = clean_study_data_complete.groupby("Drug Regimen").agg(
    {"Tumor Volume (mm3)": ["var"]}
                            )
variances
# Out:
#              Tumor Volume (mm3)
#                             var
# Drug Regimen
# Capomulin             24.947764
# Ceftamin              39.290177
# Infubinol             43.128684
# Ketapril              68.553577
# Naftisol              66.173479
# Placebo               61.168083
# Propriva              43.852013
# Ramicane              23.486704
# Stelasyn              59.450562
# Zoniferol             48.533355

# %%
#calculate the standard errors
#clean_study_data_complete.drop(columns=["Mouse ID"])
sems = clean_study_data_complete.groupby("Drug Regimen").agg(
    {"Tumor Volume (mm3)": ["sem"]}
                            )
sems["Tumor Volume (mm3)"]
# Out:
#                    sem
# Drug Regimen
# Capomulin     0.329346
# Ceftamin      0.469821
# Infubinol     0.492236
# Ketapril      0.603860
# Naftisol      0.596466
# Placebo       0.581331
# Propriva      0.544332
# Ramicane      0.320955
# Stelasyn      0.573111
# Zoniferol     0.516398

# %%
#calculate the standard deviation
#stds = clean_study_data_complete.groupby("Drug Regimen").std()
stds = clean_study_data_complete.groupby("Drug Regimen").agg(
    {"Tumor Volume (mm3)": ["std"]}
                            )
stds
#print("Standard deviation:", clean_study_data_complete.groupby("Drug Regimen").std())
# Out:
#              Tumor Volume (mm3)
#                             std
# Drug Regimen
# Capomulin              4.994774
# Ceftamin               6.268188
# Infubinol              6.567243
# Ketapril               8.279709
# Naftisol               8.134708
# Placebo                7.821003
# Propriva               6.622085
# Ramicane               4.846308
# Stelasyn               7.710419
# Zoniferol              6.966589

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
summaryDict = {
        "Mean Tumor Volume" : means,
        "Median Tumor Volume" : medians,
        "Tumor Volume Variance" : variances,
        "Tumor Volume Std. Dev." : stds,
        "Tumor Volume Std. Err." : sems
}


#df= pd.DataFrame(summaryDict)
#df
summaryDict
# Out:
# {'Mean Tumor Volume':               Timepoint  Tumor Volume (mm3)  Metastatic Sites  Age_months  \
#  Drug Regimen
#  Capomulin     21.565217           40.675741          0.713043   13.456522
#  Ceftamin      19.747191           52.591172          1.179775   13.247191
#  Infubinol     18.174157           52.884795          0.960674   16.230337
#  Ketapril      19.707447           55.235638          1.297872   15.659574
#  Naftisol      19.623656           54.331565          1.182796   12.000000
#  Placebo       18.674033           54.033581          1.441989   10.734807
#  Propriva      17.060811           52.320930          1.013514   10.006757
#  Ramicane      21.425439           40.216745          0.548246   10.684211
#  Stelasyn      19.226519           54.233149          0.872928   12.784530
#  Zoniferol     19.368132           53.236507          1.230769   12.598901
#
#                Weight (g)
#  Drug Regimen
#  Capomulin      19.965217
#  Ceftamin       27.398876
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)
df2 = clean_study_data_complete.groupby("Drug Regimen").agg(
    {"Tumor Volume (mm3)": ["mean","median", "var", "std", "sem"]}
                            )
df2

# Using the aggregation method, produce the same summary statistics in a single line
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
counts = clean_study_data_complete["Drug Regimen"].value_counts()
counts
# Out:
# Drug Regimen
# Capomulin    230
# Ramicane     228
# Ketapril     188
# Naftisol     186
# Zoniferol    182
# Stelasyn     181
# Placebo      181
# Infubinol    178
# Ceftamin     178
# Propriva     148
# Name: count, dtype: int64

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
counts.plot(kind= "bar", 
            color = ["black", "red", "green", "blue", "cyan", "yellow", "orange", "purple", "pink", "olive", "brown"], edgecolor = "black")


plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
plt.title("Number of Mice Tested by Drug Regimen")
plt.xticks(rotation =90)
plt.show()

# %%
counts.index.values
# Out:
# array(['Capomulin', 'Ramicane', 'Ketapril', 'Naftisol', 'Zoniferol',
#        'Stelasyn', 'Placebo', 'Infubinol', 'Ceftamin', 'Propriva'],
#       dtype=object)

# %%
counts.values
# Out:
# array([230, 228, 188, 186, 182, 181, 181, 178, 178, 148], dtype=int64)

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
plt.bar(counts.index.values,
        counts.values,
        color = ["black", "red", "green", "blue", "cyan", "yellow", "orange", "purple", "pink", "olive", "brown"], edgecolor = "black")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
plt.title("Number of Mice Tested by Drug Regimen")
plt.xticks(rotation =90)
plt.show()

# %%
counts = clean_study_data_complete["Sex"].value_counts()
counts
# Out:
# Sex
# Male      958
# Female    922
# Name: count, dtype: int64

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
counts.plot(
        kind= "pie",
        autopct = "%1.1f%%",
        colors = ["lightblue", "pink"]
)
plt.title("Distribution of Male Versus Female Mice in the Study")
plt.show()

# %%
counts.index.values
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
counts.values
# Out:
# array([958, 922], dtype=int64)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(
        counts.values,
        labels=counts.index.values,
        autopct = "%1.1f%%",
        colors = ["lightblue", "pink"]
)
plt.title("Distribution of Male Versus Female Mice in the Study")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
#start by getting the last (greatest) timepoint for each mouse (max time point)
#group by mouse ID -> then get timepoint (max of timepoint column)

#clean_study_data_complete.head()
maxTime = clean_study_data_complete.groupby("Mouse ID")["Timepoint"].max()
# created a series- now reset the index of the series
maxTime = maxTime.reset_index()
maxTime.head()
# Out:
#   Mouse ID  Timepoint
# 0     a203         45
# 1     a251         45
# 2     a262         45
# 3     a275         45
# 4     a366         30

# %%
clean_study_data_complete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
#merge this group DF with the original dataframe to get the tumor volume of the last timepoint
# merge to keep data for the max timepoints of each mouse ONLY

merged_data= maxTime.merge(clean_study_data_complete, on= ["Mouse ID", "Timepoint"], how = "left")
merged_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     a203         45           67.973419                 2    Infubinol
# 1     a251         45           65.525743                 1    Infubinol
# 2     a262         45           70.717621                 4      Placebo
# 3     a275         45           62.999356                 3     Ceftamin
# 4     a366         30           63.440686                 1     Stelasyn
#
#       Sex  Age_months  Weight (g)
# 0  Female          20          23
# 1  Female          21          25
# 2  Female          17          29
# 3  Female          20          28
# 4  Female          16          29

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# put the treatments in a list for a loop (and later for plot labels)
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# %%
#locate the rows which contain mice on each drug and get the tumor columes- use .loc()
for treatment in treatment_list:
        info = merged_data.loc[merged_data["Drug Regimen"] == treatment]
info
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 3       a275         45           62.999356                 3     Ceftamin
# 21      b447          0           45.000000                 0     Ceftamin
# 22      b487         25           56.057749                 1     Ceftamin
# 25      b759         30           55.742829                 1     Ceftamin
# 58      f436         15           48.722078                 2     Ceftamin
# 75      h531          5           47.784682                 0     Ceftamin
# 88      j296         45           61.849023                 3     Ceftamin
# 94      k210         45           68.923185                 3     Ceftamin
# 106     l471         45           67.748662                 1     Ceftamin
# 107     l490         30           57.918381                 3     Ceftamin
# 109     l558         10           46.784535                 0     Ceftamin
# ...

# %%
#locate the rows which contain mice on each drug and get the tumor columes- use .loc()

for treatment in treatment_list:
    #print(treatment)
      final_tumor_vol   = merged_data.loc[merged_data["Drug Regimen"] == treatment, "Tumor Volume (mm3)"]
final_tumor_vol
# Out:
# 3      62.999356
# 21     45.000000
# 22     56.057749
# 25     55.742829
# 58     48.722078
# 75     47.784682
# 88     61.849023
# 94     68.923185
# 106    67.748662
# 107    57.918381
# 109    46.784535
# 110    59.851956
# 113    64.299830
# 134    59.741901
# 150    61.433892
# 154    64.192341
# 184    45.000000
# 188    52.925348
# 189    45.000000
# 209    67.527482
# 223    45.000000
# 228    64.634949
# 231    61.386660
# 238    68.594745
# 240    64.729837
# Name: Tumor Volume (mm3), dtype: float64

# %%
#create empty list to full with tumor vol data (for plotting)
tumor_vol_list = []
for treatment in treatment_list:
    #locate the rows which contain mice on each drug and get the tumor columes- use .loc()
    final_tumor_vol   = merged_data.loc[merged_data["Drug Regimen"] == treatment, "Tumor Volume (mm3)"]
    tumor_vol_list.append(final_tumor_vol)
tumor_vol_list # prints a list of series
# Out:
# [19     38.982878
#  24     38.939633
#  61     30.485985
#  64     37.074024
#  66     40.159220
#  80     47.685963
#  83     37.311846
#  85     38.125164
#  87     38.753265
#  108    41.483008
#  115    38.846876
#  121    28.430964
#  124    33.329098
#  162    46.539206
#  163    32.377357
#  169    41.581521
#  174    23.343598
#  180    40.728578
#  183    34.455298
#  192    31.023923
#  204    40.658124
#  208    39.952347
#  220    36.041047
#  226    28.484033
#  239    31.896238
#  Name: Tumor Volume (mm3), dtype: float64,
#  6      38.407618
#  7      43.047543
#  10     38.810366
#  12     32.978522
#  33     38.342008
#  37     33.397653
#  45     37.311236
#  52     40.659006
#  70     29.128472
#  76     33.562402
#  77     36.374510
#  91     31.560470
#  93     36.134852
#  96     22.050126
#  119    30.564625
#  126    31.095335
#  157    45.220869
#  158    36.561652
#  166    37.225650
#  168    43.419381
#  177    30.276232
#  190    40.667713
# ...

# %%
#create empty list to full with tumor vol data (for plotting)
tumor_vol_list = []
for treatment in treatment_list:
    #locate the rows which contain mice on each drug and get the tumor columes- use .loc()
    final_tumor_vol   = merged_data.loc[merged_data["Drug Regimen"] == treatment, "Tumor Volume (mm3)"]
    
    # add each series to the empty tumor list
    tumor_vol_list.append(final_tumor_vol)

    # determine outliers using upper and lower bounds
    quartiles = final_tumor_vol.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    outliers = final_tumor_vol.loc[(final_tumor_vol < lower_bound) | (final_tumor_vol > upper_bound)]
    if len(outliers) == 0:
        print(f"{treatment}s potential outliers: None")
    else:
        output = f"{treatment}s potential outliers: "
        for o in outliers:
            output += f"{o}"
        print(output)
# Out:
# Capomulins potential outliers: None
# Ramicanes potential outliers: None
# Infubinols potential outliers: 36.3213458
# Ceftamins potential outliers: None

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
# customize the outliers
flierprops = dict(markerfacecolor= 'gold', markersize=16,
                markeredgecolor='black')
#customize the median line
medianprops = dict(linestyle='-', linewidth= 2.5, color='gold' )
#customize mean
meanpointprops = dict(marker='D', markeredgecolor='black',
                      markerfacecolor ='gold')
plt.boxplot(tumor_vol_list, labels = treatment_list,flierprops=flierprops, medianprops=medianprops, meanprops=meanpointprops,
            showmeans=True)
plt.ylabel('Final Tumor Volume (mm3)')
plt.title("Distribution of the Tumor Volume for Each Treatment Group")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
clean_study_data_complete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
capomulinDF = clean_study_data_complete.loc[clean_study_data_complete["Drug Regimen"] == "Capomulin"]
capomulinDF.head()
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       b128          0                45.0                 0    Capomulin
# 226     j246          0                45.0                 0    Capomulin
# 227     r554          0                45.0                 0    Capomulin
# 228     s185          0                45.0                 0    Capomulin
# 229     b742          0                45.0                 0    Capomulin
#
#         Sex  Age_months  Weight (g)
# 0    Female           9          22
# 226  Female          21          21
# 227  Female           8          17
# 228  Female           3          17
# 229    Male           7          21

# %%
l509Data = capomulinDF.loc[capomulinDF["Mouse ID"] == "l509"]
l509Data # we just need tomepoint (x) and tumor volume columns (y)
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 231      l509          0           45.000000                 0    Capomulin
# 253      l509          5           45.851193                 0    Capomulin
# 539      l509         10           46.759074                 0    Capomulin
# 881      l509         15           47.488599                 1    Capomulin
# 982      l509         20           48.070452                 2    Capomulin
# 1146     l509         25           44.006257                 2    Capomulin
# 1414     l509         30           44.708055                 2    Capomulin
# 1499     l509         35           40.207288                 2    Capomulin
# 1723     l509         40           40.770813                 2    Capomulin
# 1771     l509         45           41.483008                 3    Capomulin
#
#        Sex  Age_months  Weight (g)
# 231   Male          17          21
# 253   Male          17          21
# ...

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
plt.plot(l509Data["Timepoint"],
         l509Data["Tumor Volume (mm3)"],
         color='gold')
plt.title("Capomulin treatment of Mouse l509")
plt.xlabel("Timepoint (Days)")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
capomulinAveragesDF = capomulinDF.groupby("Mouse ID").mean("Tumor Volume (mm3)")
capomulinAveragesDF.head() #only need the y and x axis
# Out:
#           Timepoint  Tumor Volume (mm3)  Metastatic Sites  Age_months  \
# Mouse ID
# b128           22.5           41.963636               0.7         9.0
# b742           22.5           40.083699               0.0         7.0
# f966           10.0           36.505973               0.0        16.0
# g288           22.5           41.990097               0.8         3.0
# g316           22.5           44.613344               1.0        22.0
#
#           Weight (g)
# Mouse ID
# b128            22.0
# b742            21.0
# f966            17.0
# g288            19.0
# g316            22.0

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
plt.scatter(
    capomulinAveragesDF["Weight (g)"],
    capomulinAveragesDF["Tumor Volume (mm3)"],
    facecolor="gold",
    edgecolor="black",
    s=30
)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Weight")
plt.title("Average Tumor Volume vs. Mouse Weight for Capomulin Regimen")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
corr = st.pearsonr(capomulinAveragesDF["Weight (g)"], capomulinAveragesDF["Tumor Volume (mm3)"])[0]
#print(f"The correlation between mouse weight and the average tumor volume is {corr:.2f}")
corr
# Out:
# 0.841936342469472

# %%
x_values = capomulinAveragesDF["Weight (g)"]
y_values = capomulinAveragesDF["Tumor Volume (mm3)"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(capomulinAveragesDF["Weight (g)"],
                                                           capomulinAveragesDF["Tumor Volume (mm3)"])
regressValues = x_values * slope + intercept
lineEQ = f"y = {slope:.3f}x + {intercept:.2f}"

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

plt.scatter(x_values, y_values, facecolor="gold", edgecolor="black", s=50)

plt.plot(x_values, regressValues, "r-")
plt.annotate(lineEQ, (20,37), fontsize= 16, color="red")

plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Weight")
plt.title("Average Tumor Volume vs. Mouse Weight for Capomulin Regimen")
plt.show()
